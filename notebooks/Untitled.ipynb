# %%
from ultralytics import YOLO
from ultralytics import settings

# %%
print(settings)
# Out:
# JSONDict("/root/.config/Ultralytics/settings.json"):
# {
#   "settings_version": "0.0.6",
#   "datasets_dir": "/datasets",
#   "weights_dir": "/ultralytics/weights",
#   "runs_dir": "/ultralytics/runs",
#   "uuid": "716e845d5e289bfaa89d0a67b6427e855a3d9227b6f420ef4f91f4c629c20792",
#   "sync": true,
#   "api_key": "",
#   "openai_api_key": "",
#   "clearml": true,
#   "comet": true,
#   "dvc": true,
#   "hub": true,
#   "mlflow": true,
#   "neptune": true,
#   "raytune": true,
#   "tensorboard": false,
#   "wandb": false,
#   "vscode_msg": true,
#   "openvino_msg": true
# }

# %%
model = YOLO("yolo12x.pt")
# model.val(data='coco.yaml', save_json=True)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo12x.pt to 'yolo12x.pt': 100% ━━━━━━━━━━━━ 113.8MB 30.2MB/s 3.8s 3.7s<0.1s

# %%
model.info()
# Out:
# YOLO26x summary (fused): 190 layers, 55,725,948 parameters, 0 gradients, 193.9 GFLOPs
# (190, 55725948, 0, 193.8772992)

# %%
! pwd
# Out:
# /storage

# %%
! ls -la /storage
# Out:
# total 232436
# drwxr-xr-x 4 1000 root      4096 Apr 27 04:36 .
# drwxr-xr-x 1 root root      4096 Apr 23 19:38 ..
# drwxr-xr-x 2 root root      4096 Apr 21 17:27 .ipynb_checkpoints
# -rw-r--r-- 1 root root      3701 Apr 27 04:36 Untitled.ipynb
# drwxr-xr-x 2 root root      4096 Apr 21 17:23 data
# -rw-r--r-- 1 root root 119322638 Apr 23 20:13 yolo12x.pt
# -rw-r--r-- 1 root root 118667365 Apr 23 20:09 yolo26x.pt
